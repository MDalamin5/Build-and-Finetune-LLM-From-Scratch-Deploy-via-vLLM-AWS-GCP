# %% [markdown]
# # **ANN or MLP**
# - our dataset is `Fashion MNIST`
# - Multi-Class Classification Problem
#  ## ANN-Model Architecture
#  ### `input_feature` -> `(128, relue)` -> `(64, relu)` -> `(10, softmax)`
#
#  ## WorkFlow
#  - step1: dataloader object for train and test data
#  - step2: training loop
#  - step3: evaluations code

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
torch.manual_seed(42)

# %%
df = pd.read_csv("fmnist_small.csv")
df.sample(3)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 2836      5       0       0       0       0       0       0       0       0
# 2060      1       0       0       0       0       0       0       0       0
# 5105      2       0       0       0       0       0       0       0       0
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 2836       0  ...         0         0         0         0         0         0
# 2060       0  ...         0         0         0         0         0         0
# 5105       0  ...       144       157        79        74        67         0
#
#       pixel781  pixel782  pixel783  pixel784
# 2836         0         0         0         0
# 2060         0         0         0         0
# 5105         0         0         0         0
#
# [3 rows x 785 columns]
